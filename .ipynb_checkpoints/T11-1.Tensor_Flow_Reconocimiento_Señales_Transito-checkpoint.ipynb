# %% [markdown]
# # Introducción a Tensor Flow
# ## environment TensorFlow_v1

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.15.0'

# %%
x1 = tf.constant([1,2,3,4,5])
x2 = tf.constant([6,7,8,9,10])

# %%
res = tf.multiply(x1,x2)
print(res)
# Out:
# Tensor("Mul:0", shape=(5,), dtype=int32)

# %%
sess = tf.Session()
print(sess.run(res))
sess.close()
# Out:
# WARNING:tensorflow:From C:\Users\ESNEID~1\AppData\Local\Temp/ipykernel_10612/3767557646.py:1: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# [ 6 14 24 36 50]

# %%
with tf.Session() as sess:
    output = sess.run(res)
    print(output)
# Out:
# [ 6 14 24 36 50]

# %%
config = tf.ConfigProto(log_device_placement = True)
config = tf.ConfigProto(allow_soft_placement = True)
# Out:
# WARNING:tensorflow:From C:\Users\ESNEID~1\AppData\Local\Temp/ipykernel_10612/3125687599.py:1: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %% [markdown]
# # Aprendizaje neuronal de las señales de tránsito

# %%
import os
import skimage.io as imd

# %%
#Cargar datos
def load_ml_data(data_directory):
    dirs = [d for d in os.listdir(data_directory)
            if os.path.isdir(os.path.join(data_directory,d))]
    labels = []
    images = []
    for d in dirs:
        label_dir = os.path.join(data_directory, d)
        file_names = [os.path.join(label_dir,f)
                     for f in os.listdir(label_dir)
                     if f.endswith(".ppm")]
        for f in file_names:
            images.append(imd.imread(f ))
            labels.append(int(d))
    return images, labels

# %%
main_dir = "C:/Users/Esneider Infante/Documentos/Python Machine Learning Udemy/python-ml-course/datasets/belgian/"
train_data_dir = os.path.join(main_dir, "Training")
test_data_dir = os.path.join(main_dir, "Testing")

# %%
#Carga datos training
images, labels = load_ml_data(train_data_dir)

# %%
len(images)
# Out:
# 4575

# %%
type(images)
# Out:
# list

# %%
import numpy as np

# %%
images = np.array(images)
# Out:
# C:\Users\Esneider Infante\anaconda3\envs\TensorFlow_v1\lib\site-packages\ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.

# %%
labels = np.array(labels)

# %%
print(images.size)
print(images.ndim)
# Out:
# 4575
# 1

# %%
#Datos de la primera foto
images[0]
# Out:
# array([[[210, 249, 232],
#         [204, 249, 208],
#         [197, 198, 155],
#         ...,
#         [ 51,  60,  40],
#         [ 54,  64,  44],
#         [ 57,  66,  46]],
#
#        [[209, 250, 236],
#         [212, 255, 217],
#         [200, 196, 156],
#         ...,
#         [ 49,  57,  38],
#         [ 51,  59,  41],
#         [ 53,  60,  42]],
#
#        [[203, 246, 236],
#         [207, 246, 213],
#         [202, 192, 156],
#         ...,
#         [ 47,  53,  35],
#         [ 48,  54,  36],
#         [ 48,  55,  37]],
#
#        ...,
#
#        [[  2,  22,  25],
#         [ 26,  56,  77],
#         [ 71, 140, 159],
#         ...,
#         [ 84,  77,  50],
#         [ 68,  66,  41],
#         [ 56,  64,  44]],
#
#        [[  0,  22,  32],
#         [ 30,  75, 106],
#         [ 87, 176, 198],
#         ...,
#         [ 86,  80,  52],
#         [ 68,  66,  41],
#         [ 55,  63,  42]],
#
#        [[  0,  32,  50],
#         [ 42, 101, 135],
#         [121, 217, 239],
#         ...,
#         [ 87,  80,  52],
#         [ 70,  68,  43],
#         [ 58,  66,  46]]], dtype=uint8)

# %%
print(labels.ndim)
print(labels.size)
print(len(set(labels))) # Diferents labels
# Out:
# 1
# 4575
# 62

# %%
images.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
images.itemsize
# Out:
# 8

# %%
images.nbytes
# Out:
# 36600

# %%
images.nbytes/images.itemsize
# Out:
# 4575.0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(labels, len(set(labels)))
plt.show();

# %%
import random

# %%
rand_signs = random.sample(range(0, len(labels)),6)
rand_signs
# Out:
# [1988, 1553, 731, 2518, 2418, 3684]

# %%
for i in range(len(rand_signs)):
    temp_im = images[rand_signs[i]]
    plt.subplot(1,6,i+1)
    plt.axis("off")
    plt.imshow(temp_im)
    plt.subplots_adjust(wspace=0.5)
    plt.show()
    print("Forma: {0}, min:{1}, max:{2}".format(temp_im.shape,
                                               temp_im.min(),
                                               temp_im.max()))
# Out:
# Forma: (71, 68, 3), min:0, max:255
# Forma: (188, 193, 3), min:0, max:255
# Forma: (82, 84, 3), min:0, max:255
# Forma: (164, 170, 3), min:7, max:255
# Forma: (106, 81, 3), min:17, max:243
# Forma: (211, 314, 3), min:0, max:255

# %%
unique_labels = set(labels)
plt.figure(figsize=(16,9))
i = 1
for label in unique_labels:
    temp_im = images[list(labels).index(label)]
    plt.subplot(8,8,i)
    plt.axis("off")
    plt.title("Clase {0} ({1})".format(label, list(labels).count(label)))
    i+=1
    plt.imshow(temp_im)
plt.show()

# %% [markdown]
# # Modelos de Red Neuronal con Tensor Flow
# * Las imágenes no todas son del mismo tamaño
# * Hay 62 clases de imágenes, desde la 0 a la 61
# * La distribución de señales de tráfico no es uniforme, algunas salen más veces que otras

# %% [markdown]
# Se hará redimensionar el tamaña de las imagenes y convertir a escala de grises

# %%
from skimage import transform

# %%
w=9999 
h=9999
for image in images:
    if image.shape[0] < h:
        h = image.shape[0]
    if image.shape[1] < w:
        w = image.shape[1]
print("Tamaño mínimo: {0}x{1}".format(h,w))
# Out:
# Tamaño mínimo: 22x20

# %%
#Redimención a 30x30 pixeles
images30 = [transform.resize(image, (30,30)) for image in images]

# %%
rand_signs = random.sample(range(0, len(labels)),6)

for i in range(len(rand_signs)):
    temp_im = images30[rand_signs[i]]
    plt.subplot(1,6,i+1)
    plt.axis("off")
    plt.imshow(temp_im)
    plt.subplots_adjust(wspace=0.5)
    plt.show()
    print("Forma: {0}, min:{1}, max:{2}".format(temp_im.shape,
                                               temp_im.min(),
                                               temp_im.max()))
# Out:
# Forma: (30, 30, 3), min:0.07362601349457192, max:0.9951822143209214
# Forma: (30, 30, 3), min:0.06584806062091338, max:1.0
# Forma: (30, 30, 3), min:0.09390886032001856, max:0.9999999642242084
# Forma: (30, 30, 3), min:0.03536061713405394, max:0.8551466798312352
# Forma: (30, 30, 3), min:0.03645142556843352, max:0.8987380007581705
# Forma: (30, 30, 3), min:0.062055165784600144, max:0.997234704328102

# %%
#Escala de grises
from skimage.color import rgb2gray

# %%
images30 = np.array(images30)
images30 = rgb2gray(images30)

# %%
rand_signs = random.sample(range(0, len(labels)),6)

for i in range(len(rand_signs)):
    temp_im = images30[rand_signs[i]]
    plt.subplot(1,6,i+1)
    plt.axis("off")
    plt.imshow(temp_im, cmap="gray")
    plt.subplots_adjust(wspace=0.5)
    plt.show()
    print("Forma: {0}, min:{1}, max:{2}".format(temp_im.shape,
                                               temp_im.min(),
                                               temp_im.max()))
# Out:
# Forma: (30, 30), min:0.010905352743466651, max:0.7105935643735557
# Forma: (30, 30), min:0.1813084603151745, max:0.9150297089260268
# Forma: (30, 30), min:0.0531618997979957, max:0.9073019088022423
# Forma: (30, 30), min:0.06669543193150922, max:0.9999861379054339
# Forma: (30, 30), min:0.15748917973856214, max:0.6245480925925928
# Forma: (30, 30), min:0.2655388329637959, max:0.9999064418370064

# %%
#desactivar eager execution para habilitar placeholder, esto implica crear sesiones para presentar resultados
#tf.compat.v1.disable_eager_execution()
x = tf.compat.v1.placeholder(dtype=tf.float32, shape =[None, 30,30])
y = tf.compat.v1.placeholder(dtype=tf.int32, shape =[None])

images_flat = tf.contrib.layers.flatten(x)
logits = tf.contrib.layers.fully_connected(images_flat, 62, tf.nn.relu)
#funcion de perdida
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits))
#funcion para optimizar
train_opt = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)

final_pred = tf.arg_max(logits, 1)

accuracy = tf.reduce_mean(tf.cast(final_pred, tf.float32))
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\Esneider Infante\anaconda3\envs\TensorFlow_v1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\Esneider Infante\anaconda3\envs\TensorFlow_v1\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\ESNEID~1\AppData\Local\Temp/ipykernel_10612/4153873086.py:11: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\ESNEID~1\AppData\Local\Temp/ipykernel_10612/4153873086.py:13: The name tf.arg_max is deprecated. Please use tf.argmax instead.

# %%
images_flat
# Out:
# <tf.Tensor 'Flatten/flatten/Reshape:0' shape=(?, 900) dtype=float32>

# %%
logits
# Out:
# <tf.Tensor 'fully_connected/Relu:0' shape=(?, 62) dtype=float32>

# %%
loss
# Out:
# <tf.Tensor 'Mean:0' shape=() dtype=float32>

# %%
final_pred
# Out:
# <tf.Tensor 'ArgMax:0' shape=(?,) dtype=int64>

# %%
tf.set_random_seed(1234)

sess = tf.Session()

sess.run(tf.global_variables_initializer())

for i in range(301):
    _, accuracy_val = sess.run([train_opt,accuracy],
                              feed_dict={
                                  x:images30,
                                  y:list(labels)
                              })
    _, loss_val = sess.run([train_opt,loss],
                              feed_dict={
                                  x:images30,
                                  y:list(labels)
                              })
    if i%10 == 0:
        print("EPOCH", i)
        print("Eficacia: ", accuracy_val)
        print("Pérdidas: ", loss_val)
    #print("Fin del Ecpoh ", i)
# Out:
# EPOCH 0
# Eficacia:  37.71869
# Pérdidas:  4.122323
# EPOCH 10
# Eficacia:  27.416613
# Pérdidas:  3.2618518
# EPOCH 20
# Eficacia:  33.660767
# Pérdidas:  2.7967007
# EPOCH 30
# Eficacia:  35.154755
# Pérdidas:  2.4932642
# EPOCH 40
# Eficacia:  35.310165
# Pérdidas:  2.296518
# EPOCH 50
# Eficacia:  35.333553
# Pérdidas:  2.1607442
# EPOCH 60
# Eficacia:  35.372677
# Pérdidas:  2.0604653
# EPOCH 70
# Eficacia:  35.25071
# Pérdidas:  1.9822334
# EPOCH 80
# Eficacia:  35.16306
# Pérdidas:  1.9185611
# EPOCH 90
# Eficacia:  35.17639
# Pérdidas:  1.8651727
# EPOCH 100
# Eficacia:  35.159782
# Pérdidas:  1.8193761
# EPOCH 110
# Eficacia:  35.05858
# Pérdidas:  1.7793514
# EPOCH 120
# Eficacia:  35.008087
# Pérdidas:  1.7439989
# EPOCH 130
# Eficacia:  34.94929
# Pérdidas:  1.7124503
# EPOCH 140
# Eficacia:  34.88306
# Pérdidas:  1.6840203
# EPOCH 150
# Eficacia:  34.87366
# Pérdidas:  1.6581942
# EPOCH 160
# Eficacia:  34.805466
# Pérdidas:  1.6345782
# EPOCH 170
# Eficacia:  34.767212
# Pérdidas:  1.6128993
# EPOCH 180
# Eficacia:  34.776176
# Pérdidas:  1.5928992
# EPOCH 190
# Eficacia:  34.763935
# Pérdidas:  1.5743728
# EPOCH 200
# Eficacia:  34.772457
# Pérdidas:  1.5571438
# EPOCH 210
# Eficacia:  34.786667
# Pérdidas:  1.5410608
# EPOCH 220
# Eficacia:  34.769398
# Pérdidas:  1.5260065
# EPOCH 230
# Eficacia:  34.76131
# Pérdidas:  1.511869
# EPOCH 240
# Eficacia:  34.76612
# Pérdidas:  1.4985608
# EPOCH 250
# Eficacia:  34.744045
# Pérdidas:  1.4860041
# EPOCH 260
# Eficacia:  34.751476
# Pérdidas:  1.4741328
# EPOCH 270
# Eficacia:  34.74339
# Pérdidas:  1.4628872
# EPOCH 280
# Eficacia:  34.754753
# Pérdidas:  1.4522096
# EPOCH 290
# Eficacia:  34.740982
# Pérdidas:  1.4420588
# EPOCH 300
# Eficacia:  34.75082
# Pérdidas:  1.432388

# %% [markdown]
# # Evaluación de la red neuronal

# %%
#Muestra
sample_idx = random.sample(range(len(images30)),40)
sample_images = [images30[i] for i in sample_idx]
sample_labels = [labels[i] for i in sample_idx]

# %%
sample_labels
# Out:
# [41,
#  22,
#  17,
#  47,
#  22,
#  23,
#  39,
#  39,
#  61,
#  7,
#  39,
#  61,
#  18,
#  32,
#  32,
#  47,
#  40,
#  33,
#  17,
#  61,
#  37,
#  27,
#  32,
#  47,
#  45,
#  56,
#  53,
#  19,
#  47,
#  40,
#  51,
#  61,
#  61,
#  29,
#  9,
#  44,
#  53,
#  53,
#  44,
#  47]

# %%
prediction = sess.run([final_pred], feed_dict={x:sample_images})[0]

# %%
prediction
# Out:
# array([40, 22, 17, 47, 22, 28, 39, 39, 61,  7, 39, 61, 18, 32, 32, 47, 40,
#        53, 17, 61, 37, 28, 32, 47, 45, 56, 53, 19, 47, 40, 51, 61, 28, 32,
#        47, 44, 40, 53, 44, 47], dtype=int64)

# %%
sample_labels
# Out:
# [41,
#  22,
#  17,
#  47,
#  22,
#  23,
#  39,
#  39,
#  61,
#  7,
#  39,
#  61,
#  18,
#  32,
#  32,
#  47,
#  40,
#  33,
#  17,
#  61,
#  37,
#  27,
#  32,
#  47,
#  45,
#  56,
#  53,
#  19,
#  47,
#  40,
#  51,
#  61,
#  61,
#  29,
#  9,
#  44,
#  53,
#  53,
#  44,
#  47]

# %%
plt.figure(figsize=(16,20))
for i in range(len(sample_images)):
    truth = sample_labels[i]
    predi = prediction[i]
    plt.subplot(10,4,i+1)
    plt.axis("off")
    color = "green" if truth==predi else "red"
    plt.text(32,15, "Real:         {0}\nPrediction:{1}".format(truth, predi),
            fontsize=14, color = color)
    plt.imshow(sample_images[i], cmap="gray")
plt.show()

# %%
#Carga de datos de test y transformaciones necesarias

# %%
test_images, test_labels = load_ml_data(test_data_dir)

# %%
test_images30 = [transform.resize(im,(30,30)) for im in test_images]

# %%
test_images30 = rgb2gray(np.array(test_images30))

# %%
#Predicción
prediction = sess.run([final_pred], feed_dict={x:test_images30})[0]

# %%
match_count = sum([int(lo==lp) for lo, lp in zip (test_labels, prediction)])
match_count
# Out:
# 1761

# %%
acc = match_count/len(test_labels)*100
print("Eficacia de la red neuronal: {:.2f}".format(acc))
# Out:
# Eficacia de la red neuronal: 69.88
